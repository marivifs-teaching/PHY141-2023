# %%
import numpy as np

# %% [markdown]
# ### Q1
#
# (30 points) A binary star system is composed of two identical stars of mass M, radius R$_s$ and separated by distance D=100R$_s$ as measured from center to center of the stars. A planet  sits in between the two starts, midd way on the line that joiuns the starts together. A satellite is orbiting around the planet in a perfectly circular orbit of radius R$_s$ (same as the starts radii) in the plane perpendicular to the line that joins the two stars, as shown in the figure.
#
#
# * Radius of the stars R$_s$=10$^5$ km
# * Mass of the stars M$_s$=$6\times10^{30}$ kg
# * Period of the satellite around its orbit T = 3 h
# * G=6.67$6\times10^{-11}$ m$^3$kg$^{-1}$s$^{-2}$
# * Radius of the planet R$_p$=10$^2$ km
# * g=9.8m/s$^2$
#
#
#
# Provide your answers with 3 significant digits
#
#   * A (15 points) What is the mass of the planet ?
#
#   Mp=4.98$\times 10^{27}$Kg
#
#   * B (15 points) What is the escape velocity of a rocket launched from the surface of the planet vertically up along a line perpendicular to the axis connecting the two stars?
#
#
#   Use conservation of energy. At the beginning the satellite has potential energy (due to the planet and the 2 stars)
#    General formula for the potential energy of an object of mass m at distance r from another mass M: $U = -\frac{GmM}{r}$
#
#   E$_{pi}$=$ -\frac{Gm_sM_p}{R_p}$ - $ 2\frac{Gm_sM_s}{R_{ss}} $
#
#   E$_{ki}$ = $\frac{m_sv_i^2}{2} $
#
#   The potential energy at the end should be zero and the kinetic energy larger than zero.
#
#   E$_{pf}$= 0 J
#
#   E$_{kf}$ = $\frac{m_sv_f^2}{2} $ > 0
#
#   $v_i=V_{escape} =\sqrt{\large(\frac{2GM_p}{R_p} + \frac{4GM_s}{R_{ss}}\large)}=571000 m/s$

# %%
np.set_printoptions(precision=3)
# %precision 3

T=3*3600 # Period in s
Rs=1e8     # R star, m
Ms=6e30    # M star kg
G=6.67e-11 # G (m^3/kg/s^2)
D=100*Rs    # m
g=9.8      # m/s^2
#print(r/R,r/x)
vs = (2*np.pi*Rs)/T #m/s
rss = np.sqrt((D/2)**2+Rs**2)
print("vs =", vs, "m/s", "rss = ", rss, "m")
Mp=vs**2*Rs/G - Ms*2*Rs**3/rss**3
print("Mp = ", Mp , "Kg")

vscape = np.sqrt(2*G*Mp/Rs + 4*G*Ms/rss)
print("vscape =", vscape, "m/s")
# Out:
# vs = 58177.641733144315 m/s rss =  5000999900.019995 m
# Mp =  4.978477357765301e+27 Kg
# vscape = 571609.3736096863 m/s

# %% [markdown]
# ### Q2
#
# A 500 ,kg car is traveling with constant speed along a road which follows a circular path on the face of a cone. The radius of the curve is 100 m. The road is 10 m lower in height than the top of the cone. The coefficient of static friction between the road and the tires is $\mu=0.2$
#
# * A (5 points) What is the angle of the slope, $\theta$?
#
# $\tan^{-1}(\frac{10}{100}=5.71^{o})$
#
#
# * B (15 points) What is the minimum speed that the car can have without sliding off the road?
#
# Forces in horizontal direction
#
# $F_{Fr}\cos\theta-F_{N}\sin\theta=\frac{mv^{2}}{r}$
#
# Forces in vertical direction
#
# $F_{Fr}\sin\theta+F_{N}\cos\theta=mg$
#
# The maximum value of the frictional force is $F_{Fr}=\mu F_{N}$
#
# so
#
# $\mu F_{N}\cos\theta-F_{N}\sin\theta=\frac{mv^{2}}{r}$
#
# $\mu F_{N}\sin\theta+F_{N}\cos\theta=mg$
#
# Divide one equation by the other to get
#
# $\frac{\mu\cos\theta-\sin\theta}{\mu\sin\theta+\cos\theta}=\frac{v^{2}}{rg}$
#
#
#
# $v^{2}=100\times9.8\times\frac{0.2\cos 5.71^{o}-\sin 5.71^{o}}{0.2\sin 5.71^{o}+\cos 5.71^{o}}=96.09$
#
# $v=9.8\mathrm{m\,s^{-1}}$
#
# * C (5 points) What is the magnitude of the normal force exerted by the road on the car when it is traveling at this minimum speed?
#
# This can be determined from either of the force equations
#
# $F_{N}=\frac{mg}{\mu\sin\theta+\cos\theta}=\frac{9.8\times500}{0.2\sin 5.71^{o}+\cos 5.71^{o}}=4827\mathrm{N}$
#
# * D (5 points) How much work does the frictional force do on the car while it is driving around the path?
#
# Friction is perpendicular to motion so work done by friction is $0 \mathrm{J}$
#
# * E (5 points) How much work does gravity do on the car  while the car is driving around the path?
#
# Gravity is perpendicular to motion so work done by gravity is $0 \mathrm{J}$

# %% [markdown]
# ### Q3
#
# (30 points) A catapult is designed to fire a rock at a fixed angle of 45$^0$ above the horizontal. A knight begins to charge from a distance of 100 m towards the catapult at a constant speed of 10 m/s. If the catapult is fired at the same instant as the knight begins to charge then:
#
# * A (5 points)  Write equations for both components (x and y) of the rock displacement as a function of time, taking t=0s to be the time the catapult is fired.
#
# $x_r(t) = v_{0,x}t\hat{i}$ m
#
# $y_r(t) = (v_{0,y}t-0.5gt^2)\hat{j}$ m
#
# with $v_{0,x}=v_{0,y}=\frac{\sqrt{2}}{2}v_0$
#
#
#
# B (5 points) Write equations for both components (x and y) of the knight’s displacement as a function of time.
#
# $x_k(t) = (100-10t)\hat{i}$ m
#
# $y_k(t) = 0\hat{j}$ m
#
# C (10 points) What initial velocity must the rock fired from the catapult have to hit the knight?
#
# $x_r(t)=x_k(t)\rightarrow \frac{\sqrt{2}}{2}v_0t=(100-10t)$
#
# $y_r(t)=y_k(t)\rightarrow(\frac{\sqrt{2}}{2}v_0t-0.5gt^2)=0$
#
# Solving for t and v you obtain: t=3.61 s, v$_0$=25.0 m/s$
#
# * D (5 points) How much work did gravity do on the rock while it was in the air?
#
# zero, it went up as much as it went down.
#
# * (5 points) Why is the catapult designed to fire at a fixed angle of 45$^o$ above the horizontal?
#
# It is the angle of maximum range.
